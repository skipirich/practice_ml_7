# %% [markdown]
# Подгужаем необходимый набор библиотек

# %%
import pandas as pd
import numpy as np
import hyperopt
import optuna
from hyperopt import hp, fmin, tpe, Trials
from sklearn import linear_model, ensemble, metrics
from sklearn.model_selection import(
    train_test_split, 
    RandomizedSearchCV, 
    GridSearchCV, 
    cross_val_score 
)

# %% [markdown]
# Подгружаем данные, проверяем

# %%
data = pd.read_csv('data/final_task_ml_7.csv')
data.head()
# Out:
#    Activity        D1        D2    D3   D4        D5        D6        D7  \
# 0         1  0.000000  0.497009  0.10  0.0  0.132956  0.678031  0.273166
# 1         1  0.366667  0.606291  0.05  0.0  0.111209  0.803455  0.106105
# 2         1  0.033300  0.480124  0.00  0.0  0.209791  0.610350  0.356453
# 3         1  0.000000  0.538825  0.00  0.5  0.196344  0.724230  0.235606
# 4         0  0.100000  0.517794  0.00  0.0  0.494734  0.781422  0.154361
#
#          D8        D9  ...  D1767  D1768  D1769  D1770  D1771  D1772  D1773  \
# 0  0.585445  0.743663  ...      0      0      0      0      0      0      0
# 1  0.411754  0.836582  ...      1      1      1      1      0      1      0
# 2  0.517720  0.679051  ...      0      0      0      0      0      0      0
# 3  0.288764  0.805110  ...      0      0      0      0      0      0      0
# 4  0.303809  0.812646  ...      0      0      0      0      0      0      0
#
#    D1774  D1775  D1776
# 0      0      0      0
# 1      0      1      0
# 2      0      0      0
# 3      0      0      0
# 4      0      0      0
#
# [5 rows x 1777 columns]

# %% [markdown]
# Сщздаем матрицу наблюдений X и вектор ответов y

# %%
X = data.drop(['Activity'], axis=1)
y = data['Activity']

# %% [markdown]
# Разделяем выборку на тренировочную и тестовую в соотношении 80/20. Для сохранения соотношений целевого признака используем параметр stratify (стратифицированное разбиение).

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state = 1, test_size = 0.2)

# %% [markdown]
# Зафиксируем метрики без дополнительных настроек(по умолчанию)

# %%
# Создаем объект класса логистическая регрессия
log_reg = linear_model.LogisticRegression(max_iter = 50)
# Обучаем модель, минимизируя logloss
log_reg.fit(X_train, y_train)
y_test_pred = log_reg.predict(X_test)
print('f1_score на тестовом наборе: {:.2f}'.format(metrics.f1_score(y_test, y_test_pred)))
# Out:
# f1_score на тестовом наборе: 0.79
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Создаем объект класса случайный лес
random_forest = ensemble.RandomForestClassifier(random_state=42)
# Обучаем модель
random_forest.fit(X_train, y_train)
# Выводим значения метрики 
y_test_pred = random_forest.predict(X_test)
print('f1_score на тестовом наборе: {:.2f}'.format(metrics.f1_score(y_test, y_test_pred)))
# Out:
# f1_score на тестовом наборе: 0.81

# %% [markdown]
# Используем GridSearchCV для логистической регрессии

# %%
param_grid = {'penalty': ['l2', 'none'] ,# тип регурялизации
              'solver': ['lbfgs', 'saga'], # алгоритм оптимизации
              }
grid_search = GridSearchCV(
    estimator=linear_model.LogisticRegression(
        random_state=42, # генератор случайных чисел
        max_iter=50 # количество итераций на сходимость
    ), 
    param_grid=param_grid, 
    cv=5, 
    n_jobs = -1
)  
grid_search.fit(X_train, y_train) 
y_train_pred = grid_search.predict(X_train)
print('f1_score на обучающем наборе: {:.2f}'.format(metrics.f1_score(y_train, y_train_pred))) 
y_test_pred = grid_search.predict(X_test)
print('f1_score на тестовом наборе: {:.2f}'.format(metrics.f1_score(y_test, y_test_pred)))
print("Наилучшие значения гиперпараметров: {}".format(grid_search.best_params_))
# Out:
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# f1_score на обучающем наборе: 0.86
# f1_score на тестовом наборе: 0.78
# Наилучшие значения гиперпараметров: {'penalty': 'l2', 'solver': 'saga'}
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %% [markdown]
# Используем GridSearchCV для случайного дерева

# %%
param_grid = {'n_estimators': list(range(80, 200, 30)),
              'min_samples_leaf': [5],
              'max_depth': list(np.linspace(20, 40, 5, dtype=int))
              }
            
grid_search_forest = GridSearchCV(
    estimator=ensemble.RandomForestClassifier(random_state=42), 
    param_grid=param_grid, 
    cv=5, 
    n_jobs = -1
)  
grid_search_forest.fit(X_train, y_train)
y_train_pred = grid_search_forest.predict(X_train)
print('f1_score на обучающем наборе: {:.2f}'.format(metrics.f1_score(y_train, y_train_pred))) 
y_test_pred = grid_search_forest.predict(X_test)
print('f1_score на тестовом наборе: {:.2f}'.format(metrics.f1_score(y_test, y_test_pred)))
print('Наилучшие значения гиперпараметров: {}'.format(grid_search_forest.best_params_))
# Out:
# f1_score на обучающем наборе: 0.94
# f1_score на тестовом наборе: 0.82
# Наилучшие значения гиперпараметров: {'max_depth': 20, 'min_samples_leaf': 5, 'n_estimators': 140}

# %% [markdown]
# Воспользуемся RandomizedSearchCV для линейной регрессии

# %%
param_distributions = {
    'penalty': ['l2', 'none'] ,
    'solver': ['lbfgs', 'sag'],
},
            
random_search = RandomizedSearchCV(
    estimator=linear_model.LogisticRegression(random_state=42, max_iter=50), 
    param_distributions=param_distributions, 
    cv=5, 
    n_iter = 10, 
    n_jobs = -1
)
random_search.fit(X_train, y_train)
y_train_pred = random_search.predict(X_train)
print('f1_score на обучающем наборе: {:.2f}'.format(metrics.f1_score(y_train, y_train_pred)))
y_test_pred = random_search.predict(X_test)
print('f1_score на тестовом наборе: {:.2f}'.format(metrics.f1_score(y_test, y_test_pred)))
print("Наилучшие значения гиперпараметров: {}".format(random_search.best_params_))
# Out:
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:306: UserWarning: The total space of parameters 4 is smaller than n_iter=10. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# f1_score на обучающем наборе: 0.87
# f1_score на тестовом наборе: 0.79
# Наилучшие значения гиперпараметров: {'solver': 'sag', 'penalty': 'l2'}
# /home/romio/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %% [markdown]
# Воспользуемся RandomizedSearchCV дл случайного леса

# %%
param_distributions = {'n_estimators': list(range(100, 200, 30)),
              'min_samples_leaf': [5,7],
              'max_depth': list(np.linspace(10, 15, 20, 25, dtype=int))
              }
            
random_search_forest = RandomizedSearchCV(
    estimator=ensemble.RandomForestClassifier(random_state=42), 
    param_distributions=param_distributions, 
    cv=5,
    n_iter = 10, 
    n_jobs = -1
)  
random_search_forest.fit(X_train, y_train) 
y_train_pred = random_search_forest.predict(X_train)
print('f1_score на обучающем наборе: {:.2f}'.format(metrics.f1_score(y_train, y_train_pred)))
y_test_pred = random_search_forest.predict(X_test)
print('f1_score на тестовом наборе: {:.2f}'.format(metrics.f1_score(y_test, y_test_pred)))
# Out:
# f1_score на обучающем наборе: 0.94
# f1_score на тестовом наборе: 0.82

# %% [markdown]
# Воспользуемся Hyperopt для случайного леса

# %%
space={'n_estimators': hp.quniform('n_estimators', 100, 200, 1),
    'max_depth' : hp.quniform('max_depth', 15, 26, 1),
    'min_samples_leaf': hp.quniform('min_samples_leaf', 2, 10, 1)
}

# зафксируем random_state
random_state = 42
def hyperopt_rf(params, cv=5, X=X_train, y=y_train, random_state=random_state):
    # функция получает комбинацию гиперпараметров в "params"
    params = {'n_estimators': int(params['n_estimators']), 
              'max_depth': int(params['max_depth']), 
             'min_samples_leaf': int(params['min_samples_leaf'])
              }
  
    # используем эту комбинацию для построения модели
    model = ensemble.RandomForestClassifier(**params, random_state=random_state)

    # обучаем модель
    model.fit(X, y)
    score = metrics.f1_score(y, model.predict(X))
    
    # обучать модель можно также с помощью кросс-валидации
    # применим  cross validation с тем же количеством фолдов
    # score = cross_val_score(model, X, y, cv=cv, scoring="f1", n_jobs=-1).mean()

    # метрику необходимо минимизировать, поэтому ставим знак минус
    return -score

trials = Trials() # используется для логирования результатов

best=fmin(hyperopt_rf, # наша функция 
          space=space, # пространство гиперпараметров
          algo=tpe.suggest, # алгоритм оптимизации, установлен по умолчанию, задавать необязательно
          max_evals=50, # максимальное количество итераций
          trials=trials, # логирование результатов
          rstate=np.random.default_rng(random_state)# фиксируем для повторяемости результата
         )
print("Наилучшие значения гиперпараметров {}".format(best))

model = ensemble.RandomForestClassifier(
    random_state=random_state, 
    n_estimators=int(best['n_estimators']),
    max_depth=int(best['max_depth']),
    min_samples_leaf=int(best['min_samples_leaf'])
)
model.fit(X_train, y_train)
y_train_pred = model.predict(X_train)
print('f1_score на обучающем наборе: {:.2f}'.format(metrics.f1_score(y_train, y_train_pred)))
y_test_pred = model.predict(X_test)
print('f1_score на тестовом наборе: {:.2f}'.format(metrics.f1_score(y_test, y_test_pred)))
# Out:
# 100%|██████████| 20/20 [01:03<00:00,  3.15s/trial, best loss: -0.988653787181846]
# Наилучшие значения гиперпараметров {'max_depth': 18.0, 'min_samples_leaf': 2.0, 'n_estimators': 103.0}
# f1_score на обучающем наборе: 0.99
# f1_score на тестовом наборе: 0.82

# %% [markdown]
# Optuna для случайного леса

# %%
def optuna_rf(trial):
    # задаем пространства поиска гиперпараметров
    n_estimators = trial.suggest_int('n_estimators', 100, 200, 1)
    max_depth = trial.suggest_int('max_depth', 10, 30, 1)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 2, 10, 1)

    # создаем модель
    model = ensemble.RandomForestClassifier(n_estimators=n_estimators,
                                            max_depth=max_depth,
                                            min_samples_leaf=min_samples_leaf,
                                            random_state=random_state)
    # обучаем модель
    model.fit(X_train, y_train)
    score = metrics.f1_score(y_train, model.predict(X_train))

    return score

# cоздаем объект исследования
# можем напрямую указать, что нам необходимо максимизировать метрику direction="maximize"
study = optuna.create_study(study_name="RandomForestClassifier", direction="maximize")
# ищем лучшую комбинацию гиперпараметров n_trials раз
study.optimize(optuna_rf, n_trials=50)

# выводим результаты на обучающей выборке
print("Наилучшие значения гиперпараметров {}".format(study.best_params))
print("f1_score на обучающем наборе: {:.2f}".format(study.best_value))

# рассчитаем точность для тестовой выборки
model = ensemble.RandomForestClassifier(**study.best_params,random_state=random_state, )
model.fit(X_train, y_train)
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)
print('f1_score на тестовом наборе: {:.2f}'.format(metrics.f1_score(y_test, y_test_pred)))
# Out:
# [I 2022-09-08 16:07:41,916] A new study created in memory with name: RandomForestClassifier
# [I 2022-09-08 16:07:44,220] Trial 0 finished with value: 0.9602932193036041 and parameters: {'n_estimators': 120, 'max_depth': 28, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.9602932193036041.
# [I 2022-09-08 16:07:45,977] Trial 1 finished with value: 0.9036991745643533 and parameters: {'n_estimators': 112, 'max_depth': 14, 'min_samples_leaf': 9}. Best is trial 0 with value: 0.9602932193036041.
# [I 2022-09-08 16:07:50,370] Trial 2 finished with value: 0.9456985967053081 and parameters: {'n_estimators': 151, 'max_depth': 29, 'min_samples_leaf': 5}. Best is trial 0 with value: 0.9602932193036041.
# [I 2022-09-08 16:07:54,483] Trial 3 finished with value: 0.9242516799022602 and parameters: {'n_estimators': 166, 'max_depth': 16, 'min_samples_leaf': 7}. Best is trial 0 with value: 0.9602932193036041.
# [I 2022-09-08 16:07:57,275] Trial 4 finished with value: 0.9356223175965667 and parameters: {'n_estimators': 129, 'max_depth': 19, 'min_samples_leaf': 6}. Best is trial 0 with value: 0.9602932193036041.
# [I 2022-09-08 16:08:00,737] Trial 5 finished with value: 0.9020445529447665 and parameters: {'n_estimators': 176, 'max_depth': 26, 'min_samples_leaf': 10}. Best is trial 0 with value: 0.9602932193036041.
# [I 2022-09-08 16:08:04,404] Trial 6 finished with value: 0.9462759462759464 and parameters: {'n_estimators': 192, 'max_depth': 16, 'min_samples_leaf': 5}. Best is trial 0 with value: 0.9602932193036041.
# [I 2022-09-08 16:08:06,509] Trial 7 finished with value: 0.9846813725490196 and parameters: {'n_estimators': 100, 'max_depth': 16, 'min_samples_leaf': 2}. Best is trial 7 with value: 0.9846813725490196.
# [I 2022-09-08 16:08:08,354] Trial 8 finished with value: 0.9354937328034241 and parameters: {'n_estimators': 106, 'max_depth': 12, 'min_samples_leaf': 4}. Best is trial 7 with value: 0.9846813725490196.
# [I 2022-09-08 16:08:11,895] Trial 9 finished with value: 0.9527583053946966 and parameters: {'n_estimators': 195, 'max_depth': 15, 'min_samples_leaf': 4}. Best is trial 7 with value: 0.9846813725490196.
# [I 2022-09-08 16:08:14,710] Trial 10 finished with value: 0.9914110429447852 and parameters: {'n_estimators': 132, 'max_depth': 23, 'min_samples_leaf': 2}. Best is trial 10 with value: 0.9914110429447852.
# [I 2022-09-08 16:08:17,598] Trial 11 finished with value: 0.9914163090128756 and parameters: {'n_estimators': 135, 'max_depth': 23, 'min_samples_leaf': 2}. Best is trial 11 with value: 0.9914163090128756.
# [I 2022-09-08 16:08:20,543] Trial 12 finished with value: 0.9911124731841863 and parameters: {'n_estimators': 138, 'max_depth': 23, 'min_samples_leaf': 2}. Best is trial 11 with value: 0.9914163090128756.
# [I 2022-09-08 16:08:23,638] Trial 13 finished with value: 0.991421568627451 and parameters: {'n_estimators': 145, 'max_depth': 22, 'min_samples_leaf': 2}. Best is trial 13 with value: 0.991421568627451.
# [I 2022-09-08 16:08:26,950] Trial 14 finished with value: 0.9761467889908259 and parameters: {'n_estimators': 149, 'max_depth': 21, 'min_samples_leaf': 3}. Best is trial 13 with value: 0.991421568627451.
# [I 2022-09-08 16:08:30,601] Trial 15 finished with value: 0.9285714285714286 and parameters: {'n_estimators': 149, 'max_depth': 25, 'min_samples_leaf': 7}. Best is trial 13 with value: 0.991421568627451.
# [I 2022-09-08 16:08:34,951] Trial 16 finished with value: 0.9767299448867115 and parameters: {'n_estimators': 166, 'max_depth': 19, 'min_samples_leaf': 3}. Best is trial 13 with value: 0.991421568627451.
# [I 2022-09-08 16:08:37,448] Trial 17 finished with value: 0.9764597982268418 and parameters: {'n_estimators': 121, 'max_depth': 21, 'min_samples_leaf': 3}. Best is trial 13 with value: 0.991421568627451.
# [I 2022-09-08 16:08:39,709] Trial 18 finished with value: 0.9148091603053435 and parameters: {'n_estimators': 136, 'max_depth': 25, 'min_samples_leaf': 8}. Best is trial 13 with value: 0.991421568627451.
# [I 2022-09-08 16:08:42,381] Trial 19 finished with value: 0.9336594313665546 and parameters: {'n_estimators': 168, 'max_depth': 10, 'min_samples_leaf': 2}. Best is trial 13 with value: 0.991421568627451.
# [I 2022-09-08 16:08:44,985] Trial 20 finished with value: 0.9453101130461351 and parameters: {'n_estimators': 143, 'max_depth': 23, 'min_samples_leaf': 5}. Best is trial 13 with value: 0.991421568627451.
# [I 2022-09-08 16:08:47,761] Trial 21 finished with value: 0.9911070223857713 and parameters: {'n_estimators': 129, 'max_depth': 23, 'min_samples_leaf': 2}. Best is trial 13 with value: 0.991421568627451.
# [I 2022-09-08 16:08:50,993] Trial 22 finished with value: 0.9770431588613407 and parameters: {'n_estimators': 159, 'max_depth': 27, 'min_samples_leaf': 3}. Best is trial 13 with value: 0.991421568627451.
# [I 2022-09-08 16:08:53,782] Trial 23 finished with value: 0.9914163090128756 and parameters: {'n_estimators': 130, 'max_depth': 30, 'min_samples_leaf': 2}. Best is trial 13 with value: 0.991421568627451.
# [I 2022-09-08 16:08:56,228] Trial 24 finished with value: 0.9761613691931541 and parameters: {'n_estimators': 120, 'max_depth': 30, 'min_samples_leaf': 3}. Best is trial 13 with value: 0.991421568627451.
# [I 2022-09-08 16:08:58,909] Trial 25 finished with value: 0.955806156659555 and parameters: {'n_estimators': 141, 'max_depth': 18, 'min_samples_leaf': 4}. Best is trial 13 with value: 0.991421568627451.
# [I 2022-09-08 16:09:02,258] Trial 26 finished with value: 0.991421568627451 and parameters: {'n_estimators': 157, 'max_depth': 21, 'min_samples_leaf': 2}. Best is trial 13 with value: 0.991421568627451.
# [I 2022-09-08 16:09:05,878] Trial 27 finished with value: 0.9758335882532885 and parameters: {'n_estimators': 183, 'max_depth': 21, 'min_samples_leaf': 3}. Best is trial 13 with value: 0.991421568627451.
# [I 2022-09-08 16:09:08,610] Trial 28 finished with value: 0.9361051666157137 and parameters: {'n_estimators': 157, 'max_depth': 30, 'min_samples_leaf': 6}. Best is trial 13 with value: 0.991421568627451.
# [I 2022-09-08 16:09:11,511] Trial 29 finished with value: 0.9574793514836342 and parameters: {'n_estimators': 155, 'max_depth': 28, 'min_samples_leaf': 4}. Best is trial 13 with value: 0.991421568627451.
# [I 2022-09-08 16:09:13,746] Trial 30 finished with value: 0.9566544566544566 and parameters: {'n_estimators': 125, 'max_depth': 18, 'min_samples_leaf': 4}. Best is trial 13 with value: 0.991421568627451.
# [I 2022-09-08 16:09:16,862] Trial 31 finished with value: 0.9898989898989901 and parameters: {'n_estimators': 144, 'max_depth': 24, 'min_samples_leaf': 2}. Best is trial 13 with value: 0.991421568627451.
# [I 2022-09-08 16:09:19,261] Trial 32 finished with value: 0.9920343137254902 and parameters: {'n_estimators': 113, 'max_depth': 20, 'min_samples_leaf': 2}. Best is trial 32 with value: 0.9920343137254902.
# [I 2022-09-08 16:09:21,511] Trial 33 finished with value: 0.9791666666666667 and parameters: {'n_estimators': 112, 'max_depth': 20, 'min_samples_leaf': 3}. Best is trial 32 with value: 0.9920343137254902.
# [I 2022-09-08 16:09:23,843] Trial 34 finished with value: 0.9901900674432864 and parameters: {'n_estimators': 112, 'max_depth': 18, 'min_samples_leaf': 2}. Best is trial 32 with value: 0.9920343137254902.
# [I 2022-09-08 16:09:26,172] Trial 35 finished with value: 0.9761759315821625 and parameters: {'n_estimators': 116, 'max_depth': 21, 'min_samples_leaf': 3}. Best is trial 32 with value: 0.9920343137254902.
# [I 2022-09-08 16:09:28,416] Trial 36 finished with value: 0.9443425076452601 and parameters: {'n_estimators': 125, 'max_depth': 28, 'min_samples_leaf': 5}. Best is trial 32 with value: 0.9920343137254902.
# [I 2022-09-08 16:09:31,915] Trial 37 finished with value: 0.9880478087649402 and parameters: {'n_estimators': 173, 'max_depth': 17, 'min_samples_leaf': 2}. Best is trial 32 with value: 0.9920343137254902.
# [I 2022-09-08 16:09:33,569] Trial 38 finished with value: 0.888002454740718 and parameters: {'n_estimators': 108, 'max_depth': 13, 'min_samples_leaf': 10}. Best is trial 32 with value: 0.9920343137254902.
# [I 2022-09-08 16:09:36,725] Trial 39 finished with value: 0.916310323762981 and parameters: {'n_estimators': 153, 'max_depth': 20, 'min_samples_leaf': 8}. Best is trial 32 with value: 0.9920343137254902.
# [I 2022-09-08 16:09:41,265] Trial 40 finished with value: 0.9923430321592649 and parameters: {'n_estimators': 162, 'max_depth': 25, 'min_samples_leaf': 2}. Best is trial 40 with value: 0.9923430321592649.
# [I 2022-09-08 16:09:44,683] Trial 41 finished with value: 0.9917304747320062 and parameters: {'n_estimators': 163, 'max_depth': 26, 'min_samples_leaf': 2}. Best is trial 40 with value: 0.9923430321592649.
# [I 2022-09-08 16:09:48,114] Trial 42 finished with value: 0.9917304747320062 and parameters: {'n_estimators': 163, 'max_depth': 26, 'min_samples_leaf': 2}. Best is trial 40 with value: 0.9923430321592649.
# [I 2022-09-08 16:09:51,367] Trial 43 finished with value: 0.9770290964777948 and parameters: {'n_estimators': 163, 'max_depth': 26, 'min_samples_leaf': 3}. Best is trial 40 with value: 0.9923430321592649.
# [I 2022-09-08 16:09:55,218] Trial 44 finished with value: 0.992651561543172 and parameters: {'n_estimators': 183, 'max_depth': 25, 'min_samples_leaf': 2}. Best is trial 44 with value: 0.992651561543172.
# [I 2022-09-08 16:09:58,736] Trial 45 finished with value: 0.9767441860465117 and parameters: {'n_estimators': 178, 'max_depth': 26, 'min_samples_leaf': 3}. Best is trial 44 with value: 0.992651561543172.
# [I 2022-09-08 16:10:02,213] Trial 46 finished with value: 0.9580911593759559 and parameters: {'n_estimators': 188, 'max_depth': 27, 'min_samples_leaf': 4}. Best is trial 44 with value: 0.992651561543172.
# [I 2022-09-08 16:10:05,804] Trial 47 finished with value: 0.992651561543172 and parameters: {'n_estimators': 172, 'max_depth': 25, 'min_samples_leaf': 2}. Best is trial 44 with value: 0.992651561543172.
# [I 2022-09-08 16:10:09,381] Trial 48 finished with value: 0.9917304747320062 and parameters: {'n_estimators': 172, 'max_depth': 24, 'min_samples_leaf': 2}. Best is trial 44 with value: 0.992651561543172.
# [I 2022-09-08 16:10:12,915] Trial 49 finished with value: 0.9782542113323124 and parameters: {'n_estimators': 181, 'max_depth': 25, 'min_samples_leaf': 3}. Best is trial 44 with value: 0.992651561543172.
# Наилучшие значения гиперпараметров {'n_estimators': 183, 'max_depth': 25, 'min_samples_leaf': 2}
# f1_score на обучающем наборе: 0.99
# f1_score на тестовом наборе: 0.82
